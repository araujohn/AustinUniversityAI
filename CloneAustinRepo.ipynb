# %% [markdown]
# <a href="https://colab.research.google.com/github/araujohn/AustinUniversityAI/blob/main/CloneAustinRepo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
github_token = userdata.get('GITHUB_TOKEN')
username = "araujohn"
repository = "AustinUniversityAI"
repository_url = f"https://{github_token}@github.com/{username}/{repository}.git"
# !git clone $repository_url
# Out:
# Cloning into 'AustinUniversityAI'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 44 (delta 19), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 22.35 KiB | 7.45 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %%
# %cd {repository}
# Out:
# /content/AustinUniversityAI

# %%
# !git config --global user.email "john.araujo@rktsolutions.ca"
# !git config --global user.name "$username"
# !git config pull.rebase false  # merge (the default strategy)
# !git config pull.rebase true   # rebase
# !git config pull.ff only       # fast-forward only

# %%
# check the status of google repository
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# to stage all changes in the repository.
# !git add .

# %%
# !git rm --cached AustinUniversityAI
# Out:
# error: the following file has staged content different from both the
# file and the HEAD:
#     AustinUniversityAI
# (use -f to force removal)

# %%
# to commit the staged changes.
# !git commit -m "Your commit message"
# Out:
# [main 4f03d84] Your commit message
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  rename External_data_Local_Files,_Drive,_Sheets,_and_Cloud_Storage.ipynb => 01-python-foundation/External_data_Local_Files_Drive_Sheets_and_Cloud_Storage.ipynb (100%)

# %%
# !git merge -m "Your commit message"
# Out:
# Already up to date.

# %%
#  committed changes to the remote repository.

# !git push origin main
# Out:
# remote: Permission to araujohn/AustinUniversityAI.git denied to araujohn.
# fatal: unable to access 'https://github.com/araujohn/AustinUniversityAI.git/': The requested URL returned error: 403

# %%
# !git remote -v
# Out:
# origin	https://github.com/araujohn/AustinUniversityAI.git (fetch)
# origin	https://github.com/araujohn/AustinUniversityAI.git (push)

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 952 bytes | 952.00 KiB/s, done.
# From https://github.com/araujohn/AustinUniversityAI
#  * branch            main       -> FETCH_HEAD
#    e5e49e7..786aea9  main       -> origin/main
# Updating e5e49e7..786aea9
# Fast-forward
#  01-python-foundation/test.ipynb | 1 +
#  1 file changed, 1 insertion(+)
#  create mode 100644 01-python-foundation/test.ipynb

# %%
# %cd {repository}
# Out:
# [Errno 2] No such file or directory: '{repository}'
# /content/AustinUniversityAI

# %%
# get a list of the current repository origins
# !git config --list
# Out:
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# user.email=john.araujo@rktsolutions.ca
# user.name=araujohn
# core.repositoryformatversion=0
# core.filemode=true
# core.bare=false
# core.logallrefupdates=true
# remote.origin.url=https://github.com/araujohn/AustinUniversityAI.git
# remote.origin.fetch=+refs/heads/*:refs/remotes/origin/*
# branch.main.remote=origin
# branch.main.merge=refs/heads/main

# %%
# %mv /content/AustinUniversityAI/External_data_Local_Files,_Drive,_Sheets,_and_Cloud_Storage.ipynb /content/AustinUniversityAI/01-python-foundation
