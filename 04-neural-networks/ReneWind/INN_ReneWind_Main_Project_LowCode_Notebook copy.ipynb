# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ## Business Context

# %% [markdown]
# Renewable energy sources play an increasingly important role in the global energy mix, as the effort to reduce the environmental impact of energy production increases.
#
# Out of all the renewable energy alternatives, wind energy is one of the most developed technologies worldwide. The U.S Department of Energy has put together a guide to achieving operational efficiency using predictive maintenance practices.
#
# Predictive maintenance uses sensor information and analysis methods to measure and predict degradation and future component capability. The idea behind predictive maintenance is that failure patterns are predictable and if component failure can be predicted accurately and the component is replaced before it fails, the costs of operation and maintenance will be much lower.
#
# The sensors fitted across different machines involved in the process of energy generation collect data related to various environmental factors (temperature, humidity, wind speed, etc.) and additional features related to various parts of the wind turbine (gearbox, tower, blades, break, etc.).

# %% [markdown]
# ## Objective

# %% [markdown]
# “ReneWind” is a company working on improving the machinery/processes involved in the production of wind energy using machine learning and has collected data of generator failure of wind turbines using sensors. They have shared a ciphered version of the data, as the data collected through sensors is confidential (the type of data collected varies with companies). Data has 40 predictors, 20000 observations in the training set and 5000 in the test set.
#
# The objective is to build various classification models, tune them, and find the best one that will help identify failures so that the generators could be repaired before failing/breaking to reduce the overall maintenance cost.
# The nature of predictions made by the classification model will translate as follows:
#
# - True positives (TP) are failures correctly predicted by the model. These will result in repairing costs.
# - False negatives (FN) are real failures where there is no detection by the model. These will result in replacement costs.
# - False positives (FP) are detections where there is no failure. These will result in inspection costs.
#
# It is given that the cost of repairing a generator is much less than the cost of replacing it, and the cost of inspection is less than the cost of repair.
#
# “1” in the target variables should be considered as “failure” and “0” represents “No failure”.

# %% [markdown]
# ## Data Description

# %% [markdown]
# The data provided is a transformed version of the original data which was collected using sensors.
#
# - Train.csv - To be used for training and tuning of models.
# - Test.csv - To be used only for testing the performance of the final best model.
#
# Both the datasets consist of 40 predictor variables and 1 target variable.

# %% [markdown]
# # **Please read the instructions carefully before starting the project.**
# This is a commented Jupyter IPython Notebook file in which all the instructions and tasks to be performed are mentioned.
# * Blanks '_______' are provided in the notebook that
# needs to be filled with an appropriate code to get the correct result. With every '_______' blank, there is a comment that briefly describes what needs to be filled in the blank space.
# * Identify the task to be performed correctly, and only then proceed to write the required code.
# * Fill the code wherever asked by the commented lines like "# write your code here" or "# complete the code". Running incomplete code may throw error.
# * Please run the codes in a sequential manner from the beginning to avoid any unnecessary errors.
# * Add the results/observations (wherever mentioned) derived from the analysis in the presentation and submit the same.

# %% [markdown]
# # **Installing and Importing the necessary libraries**

# %%
# Installing the libraries with the specified version
#%pip install --no-deps tensorflow scikit-learn matplotlib seaborn numpy pandas -q --user --no-warn-script-location

# %% [markdown]
# **Note**:
# - After running the above cell, kindly restart the runtime (for Google Colab) or notebook kernel (for Jupyter Notebook), and run all cells sequentially from the next cell.
# - On executing the above line of code, you might see a warning regarding package dependencies. This error message can be ignored as the above code ensures that all necessary libraries and their dependencies are maintained to successfully execute the code in ***this notebook***.

# %%
#Imports the tensorflow,keras and layers.
import tensorflow
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dense, Input, Dropout,BatchNormalization
from tensorflow.keras import backend

# Library for data manipulation and analysis.
import pandas as pd
# Fundamental package for scientific computing.
import numpy as np
#splitting datasets into training and testing sets.
from sklearn.model_selection import train_test_split
#Imports tools for data preprocessing including label encoding, one-hot encoding, and standard scaling
from sklearn.preprocessing import LabelEncoder, OneHotEncoder,StandardScaler
#Imports a class for imputing missing values in datasets.
from sklearn.impute import SimpleImputer
#Imports the Matplotlib library for creating visualizations.
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# Imports the Seaborn library for statistical data visualization.
import seaborn as sns
# Time related functions.
import time
#Imports functions for evaluating the performance of machine learning models
from sklearn.metrics import confusion_matrix, f1_score,accuracy_score, recall_score, precision_score, classification_report
#Imports metrics from
from sklearn import metrics



# to suppress unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Loading the Data**

# %%
# uncomment and run the following lines for Google Colab
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#%cd {os.path.dirname(os.path.abspath('__file__'))}
import os
print(f"Current Directory: {os.getcwd()}")
df = pd.read_csv('./Train.csv')    # Complete the code to import the training data
df_test = pd.read_csv('./Test.csv')    # Complete the code to import the test data
# Out:
# Current Directory: c:\Users\JohnAraujo\workspace\AustinUniversity\04-neural-networks\ReneWind

# %% [markdown]
# # **Data Overview**

# %% [markdown]
# The initial steps to get an overview of any dataset is to:
# - observe the first few rows of the dataset, to check whether the dataset has been loaded properly or not
# - get information about the number of rows and columns in the dataset
# - find out the data types of the columns to ensure that data is stored in the preferred format and the value of each property is as expected.
# - check the statistical summary of the dataset to get an overview of the numerical columns of the data

# %% [markdown]
# ## Checking the shape of the dataset

# %%
# Checking the number of rows and columns in the training data
df.shape # Complete the code to print the shape of the train data
# Out:
# (20000, 41)

# %%
# Checking the number of rows and columns in the test data
df_test.shape # Complete the code to print the shape of the test data
# Out:
# (5000, 41)

# %%
# let's create a copy of the training data
data = df.copy()

# %%
# let's create a copy of the testing  data
data_test = df_test.copy()

# %% [markdown]
# ## Displaying the first few rows of the dataset

# %%
# let's view the first 5 rows of the data
data.head() # Complete the code to view the first five rows of the train data
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -4.464606 -4.679129  3.101546  0.506130 -0.221083 -2.032511 -2.910870
# 1  3.365912  3.653381  0.909671 -1.367528  0.332016  2.358938  0.732600
# 2 -3.831843 -5.824444  0.634031 -2.418815 -1.773827  1.016824 -2.098941
# 3  1.618098  1.888342  7.046143 -1.147285  0.083080 -1.529780  0.207309
# 4 -0.111440  3.872488 -3.758361 -2.982897  3.792714  0.544960  0.205433
#
#          V8        V9       V10  ...       V32       V33        V34       V35  \
# 0  0.050714 -1.522351  3.761892  ...  3.059700 -1.690440   2.846296  2.235198
# 1 -4.332135  0.565695 -0.101080  ... -1.795474  3.032780  -2.467514  1.894599
# 2 -3.173204 -2.081860  5.392621  ... -0.257101  0.803550   4.086219  2.292138
# 3 -2.493629  0.344926  2.118578  ... -3.584425 -2.577474   1.363769  0.622714
# 4  4.848994 -1.854920 -6.220023  ...  8.265896  6.629213 -10.068689  1.222987
#
#         V36       V37       V38       V39       V40  Target
# 0  6.667486  0.443809 -2.369169  2.950578 -3.480324       0
# 1 -2.297780 -1.731048  5.908837 -0.386345  0.616242       0
# 2  5.360850  0.351993  2.940021  3.839160 -4.309402       0
# 3  5.550100 -1.526796  0.138853  3.101430 -1.277378       0
# 4 -3.229763  1.686909 -2.163896 -3.644622  6.510338       0
#
# [5 rows x 41 columns]

# %%
#viewing first 5 rows of the test data
data_test.head() # Complete the code to view the first five rows of the test data
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.613489 -3.819640  2.202302  1.300420 -1.184929 -4.495964 -1.835817
# 1  0.389608 -0.512341  0.527053 -2.576776 -1.016766  2.235112 -0.441301
# 2 -0.874861 -0.640632  4.084202 -1.590454  0.525855 -1.957592 -0.695367
# 3  0.238384  1.458607  4.014528  2.534478  1.196987 -3.117330 -0.924035
# 4  5.828225  2.768260 -1.234530  2.809264 -1.641648 -1.406698  0.568643
#
#          V8        V9       V10  ...       V32       V33       V34       V35  \
# 0  4.722989  1.206140 -0.341909  ...  2.291204 -5.411388  0.870073  0.574479
# 1 -4.405744 -0.332869  1.966794  ... -2.474936  2.493582  0.315165  2.059288
# 2  1.347309 -1.732348  0.466500  ... -1.318888 -2.997464  0.459664  0.619774
# 3  0.269493  1.322436  0.702345  ...  3.517918 -3.074085 -0.284220  0.954576
# 4  0.965043  1.918379 -2.774855  ...  1.773841 -1.501573 -2.226702  4.776830
#
#         V36       V37        V38       V39       V40  Target
# 0  4.157191  1.428093 -10.511342  0.454664 -1.448363       0
# 1  0.683859 -0.485452   5.128350  1.720744 -1.488235       0
# 2  5.631504  1.323512  -1.752154  1.808302  1.675748       0
# 3  3.029331 -1.367198  -3.412140  0.906000 -2.450889       0
# 4 -6.559698 -0.805551  -0.276007 -3.858207 -0.537694       0
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Checking the data types of the columns in the dataset

# %%
# let's check the data types of the columns in the dataset
data.info() # Complete the code to view the data types of the columns in the train data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 41 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      19982 non-null  float64
#  1   V2      19982 non-null  float64
#  2   V3      20000 non-null  float64
#  3   V4      20000 non-null  float64
#  4   V5      20000 non-null  float64
#  5   V6      20000 non-null  float64
#  6   V7      20000 non-null  float64
#  7   V8      20000 non-null  float64
#  8   V9      20000 non-null  float64
#  9   V10     20000 non-null  float64
#  10  V11     20000 non-null  float64
#  11  V12     20000 non-null  float64
#  12  V13     20000 non-null  float64
#  13  V14     20000 non-null  float64
#  14  V15     20000 non-null  float64
#  15  V16     20000 non-null  float64
#  16  V17     20000 non-null  float64
#  17  V18     20000 non-null  float64
#  18  V19     20000 non-null  float64
#  19  V20     20000 non-null  float64
#  20  V21     20000 non-null  float64
#  21  V22     20000 non-null  float64
#  22  V23     20000 non-null  float64
#  23  V24     20000 non-null  float64
#  24  V25     20000 non-null  float64
#  25  V26     20000 non-null  float64
#  26  V27     20000 non-null  float64
#  27  V28     20000 non-null  float64
#  28  V29     20000 non-null  float64
#  29  V30     20000 non-null  float64
#  30  V31     20000 non-null  float64
#  31  V32     20000 non-null  float64
#  32  V33     20000 non-null  float64
#  33  V34     20000 non-null  float64
#  34  V35     20000 non-null  float64
#  35  V36     20000 non-null  float64
#  36  V37     20000 non-null  float64
#  37  V38     20000 non-null  float64
#  38  V39     20000 non-null  float64
#  39  V40     20000 non-null  float64
#  40  Target  20000 non-null  int64
# dtypes: float64(40), int64(1)
# memory usage: 6.3 MB

# %% [markdown]
# - Converting Target column to float

# %%
data['Target'] = data['Target'].astype(float)

# %% [markdown]
# Now checking for test data

# %%
data_test.info() # Complete the code to view the data types of the columns in the test data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 41 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      4995 non-null   float64
#  1   V2      4994 non-null   float64
#  2   V3      5000 non-null   float64
#  3   V4      5000 non-null   float64
#  4   V5      5000 non-null   float64
#  5   V6      5000 non-null   float64
#  6   V7      5000 non-null   float64
#  7   V8      5000 non-null   float64
#  8   V9      5000 non-null   float64
#  9   V10     5000 non-null   float64
#  10  V11     5000 non-null   float64
#  11  V12     5000 non-null   float64
#  12  V13     5000 non-null   float64
#  13  V14     5000 non-null   float64
#  14  V15     5000 non-null   float64
#  15  V16     5000 non-null   float64
#  16  V17     5000 non-null   float64
#  17  V18     5000 non-null   float64
#  18  V19     5000 non-null   float64
#  19  V20     5000 non-null   float64
#  20  V21     5000 non-null   float64
#  21  V22     5000 non-null   float64
#  22  V23     5000 non-null   float64
#  23  V24     5000 non-null   float64
#  24  V25     5000 non-null   float64
#  25  V26     5000 non-null   float64
#  26  V27     5000 non-null   float64
#  27  V28     5000 non-null   float64
#  28  V29     5000 non-null   float64
#  29  V30     5000 non-null   float64
#  30  V31     5000 non-null   float64
#  31  V32     5000 non-null   float64
#  32  V33     5000 non-null   float64
#  33  V34     5000 non-null   float64
#  34  V35     5000 non-null   float64
#  35  V36     5000 non-null   float64
#  36  V37     5000 non-null   float64
#  37  V38     5000 non-null   float64
#  38  V39     5000 non-null   float64
#  39  V40     5000 non-null   float64
#  40  Target  5000 non-null   int64
# dtypes: float64(40), int64(1)
# memory usage: 1.6 MB

# %% [markdown]
# Converting Target to float

# %%
data_test['Target'] = data_test['Target'].astype(float)

# %% [markdown]
# ## Checking for duplicate values

# %%
# let's check for duplicate values in the data
data.duplicated() # Complete the code to check for duplicate values in the train data
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# 19999    False
# Length: 20000, dtype: bool

# %% [markdown]
# ## Checking for missing values

# %%
# let's check for missing values in the data
data.isnull().sum()
# Out:
# V1        18
# V2        18
# V3         0
# V4         0
# V5         0
# V6         0
# V7         0
# V8         0
# V9         0
# V10        0
# V11        0
# V12        0
# V13        0
# V14        0
# V15        0
# V16        0
# V17        0
# V18        0
# V19        0
# V20        0
# V21        0
# V22        0
# V23        0
# V24        0
# V25        0
# V26        0
# V27        0
# V28        0
# V29        0
# V30        0
# V31        0
# V32        0
# V33        0
# V34        0
# V35        0
# V36        0
# V37        0
# V38        0
# V39        0
# V40        0
# Target     0
# dtype: int64

# %%
# let's check for missing values in the test data
data_test.isnull().sum() #
# Out:
# V1        5
# V2        6
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# V29       0
# V30       0
# V31       0
# V32       0
# V33       0
# V34       0
# V35       0
# V36       0
# V37       0
# V38       0
# V39       0
# V40       0
# Target    0
# dtype: int64

# %% [markdown]
# ## Statistical summary of the dataset

# %%
# let's view the statistical summary of the numerical columns in the data
data.describe().T # Complete the code to view the statistical summary of the train data
# Out:
#           count      mean       std        min       25%       50%       75%  \
# V1      19982.0 -0.271996  3.441625 -11.876451 -2.737146 -0.747917  1.840112
# V2      19982.0  0.440430  3.150784 -12.319951 -1.640674  0.471536  2.543967
# V3      20000.0  2.484699  3.388963 -10.708139  0.206860  2.255786  4.566165
# V4      20000.0 -0.083152  3.431595 -15.082052 -2.347660 -0.135241  2.130615
# V2      13.089269
# V3      17.090919
# V4      13.236381
# V5       8.133797
# V6       6.975847
# V7       8.006091
# V8      11.679495
# V9       8.137580
# V10      8.108472
# V11     11.826433
# V12     15.080698
# V13     15.419616
# V14      5.670664
# V15     12.246455
# V16     13.583212
# V17     16.756432
# V18     13.179863
# V19     13.237742
# V20     16.052339
# V21     13.840473
# V22      7.409856
# V23     14.458734
# V24     17.163291
# V25      8.223389
# V26     16.836410
# V27     17.560404
# V28      6.527643
# V29     10.722055
# V30     12.505812
# V31     17.255090
# V32     23.633187
# V33     16.692486
# V34     14.358213
# V35     15.291065
# V36     19.329576
# V37      7.467006
# V38     15.289923
# V39      7.759877
# V40     10.654265
# Target   1.000000

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# ## Univariate analysis

# %%
# function to plot a boxplot and a histogram along the same scale.


def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to the show density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data= data, x= feature, ax= ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %% [markdown]
# ### Variables V1 to V29

# %%
for feature in df.columns:
    histogram_boxplot(df, feature, figsize=(12, 7), kde=False, bins=None)

# %% [markdown]
# ### Checking the distrubution of Target variable

# %%
# For train data
df["Target"].value_counts(1)
# Out:
# Target
# 0    0.9445
# 1    0.0555
# Name: proportion, dtype: float64

# %%
# For test data
df_test["Target"].value_counts(normalize=True) # Complete the code to display the proportion of the target variable in the test data
# Out:
# Target
# 0    0.9436
# 1    0.0564
# Name: proportion, dtype: float64

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Correlation Check

# %%
cols_list = df.select_dtypes(include=np.number).columns.tolist()
cols_list.remove("Target")

plt.figure(figsize=(20, 20))
sns.heatmap(
    df[cols_list].corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral"
)
plt.show()

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# ## Data Preparation for Modeling

# %%
# Dividing train data into X and y
X = data.drop(columns = ["Target"] , axis=1) # Complete the code to remove the column named 'Target'
y = data["Target"] # Complete the code to select the column named 'Target'

# %% [markdown]
# **Since we already have a separate test set, we don't need to divide data into train, valiation and test**

# %%
# Splitting data into training and validation set:

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.2, random_state=1, stratify=y # Complete the code to define the test size
)

# %%
# Checking the number of rows and columns in the X_train data
X_train.shape
# Out:
# (16000, 40)

# %%
# Checking the number of rows and columns in the X_val data
X_val.shape
# Out:
# (4000, 40)

# %%
# Dividing test data into X_test and y_test
X_test = data_test.drop(columns = ['Target'] , axis= 1) # Complete the code to remove the target column
y_test = data_test["Target"] # Complete the code to select the target column

# %%
# Checking the number of rows and columns in the X_test data
X_test.shape
# Out:
# (5000, 40)

# %% [markdown]
# ## Missing Value Imputation

# %% [markdown]
# - There were few missing values in V1 and V2, we will impute them using the median.
# - And to avoid data leakage we will impute missing values after splitting train data into train and validation sets.

# %%
imputer = SimpleImputer(strategy="median")

# %%
# Fit and transform the train data
X_train = pd.DataFrame(imputer.fit_transform(X_train), columns=X_train.columns)

# Transform the validation data
X_val = pd.DataFrame(imputer.transform(X_val), columns=X_train.columns)    # Complete the code to impute missing values in the validation set while accounting for data leakage

# Transform the test data
X_test = pd.DataFrame(imputer.transform(X_test), columns=X_train.columns)    # Complete the code to impute missing values in the test set while accounting for data leakage

# %%
# Checking that no column has missing values in train or test sets
print(X_train.isna().sum())
print("-" * 30)
print(X_val.isna().sum())
print("-" * 30)
print(X_test.isna().sum())
# Out:
# V1     0
# V2     0
# V3     0
# V4     0
# V5     0
# V6     0
# V7     0
# V8     0
# V9     0
# V10    0
# V11    0
# V12    0
# V13    0
# V14    0
# V15    0
# V16    0
# V17    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# V29    0
# V30    0
# V31    0
# V32    0
# V33    0
# V34    0
# V35    0
# V36    0
# V37    0
# V38    0
# V39    0
# V40    0
# dtype: int64
# ------------------------------
# V1     0
# V2     0
# V3     0
# V4     0
# V5     0
# V6     0
# V7     0
# V8     0
# V9     0
# V10    0
# V11    0
# V12    0
# V13    0
# V14    0
# V15    0
# V16    0
# V17    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# V29    0
# V30    0
# V31    0
# V32    0
# V33    0
# V34    0
# V35    0
# V36    0
# V37    0
# V38    0
# V39    0
# V40    0
# dtype: int64
# ------------------------------
# V1     0
# V2     0
# V3     0
# V4     0
# V5     0
# V6     0
# V7     0
# V8     0
# V9     0
# V10    0
# V11    0
# V12    0
# V13    0
# V14    0
# V15    0
# V16    0
# V17    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# V29    0
# V30    0
# V31    0
# V32    0
# V33    0
# V34    0
# V35    0
# V36    0
# V37    0
# V38    0
# V39    0
# V40    0
# dtype: int64

# %%
y_train = y_train.to_numpy()
y_val = y_val.to_numpy()
y_test = y_test.to_numpy()

# %% [markdown]
# # **Model Building**

# %% [markdown]
# ## Model Evaluation Criterion

# %% [markdown]
# - Write down the metric of choice with rationale here

# %% [markdown]
# **We are now done with pre-processing and evaluation criterion, so let's start building the model.**

# %% [markdown]
# ## Utility Functions

# %%
def plot(history, name):
    """
    Function to plot loss/accuracy

    history: an object which stores the metrics and losses.
    name: can be one of Loss or Accuracy
    """
    fig, ax = plt.subplots() #Creating a subplot with figure and axes.
    plt.plot(history.history[name]) #Plotting the train accuracy or train loss
    plt.plot(history.history['val_'+name]) #Plotting the validation accuracy or validation loss

    plt.title('Model ' + name.capitalize()) #Defining the title of the plot.
    plt.ylabel(name.capitalize()) #Capitalizing the first letter.
    plt.xlabel('Epoch') #Defining the label for the x-axis.
    fig.legend(['Train', 'Validation'], loc="outside right upper") #Defining the legend, loc controls the position of the legend.

# %%
# defining a function to compute different metrics to check performance of a classification model built using statsmodels
def model_performance_classification(
    model, predictors, target, threshold=0.5
):
    """
    Function to compute different metrics to check classification model performance

    model: classifier
    predictors: independent variables
    target: dependent variable
    threshold: threshold for classifying the observation as class 1
    """

    # checking which probabilities are greater than threshold
    pred = model.predict(predictors) > threshold
    # pred_temp = model.predict(predictors) > threshold
    # # rounding off the above values to get classes
    # pred = np.round(pred_temp)

    acc = accuracy_score(target, pred)  # to compute Accuracy
    recall = recall_score(target, pred, average='macro')  # to compute Recall
    precision = precision_score(target, pred, average='macro')  # to compute Precision
    f1 = f1_score(target, pred, average='macro')  # to compute F1-score

    # creating a dataframe of metrics
    df_perf = pd.DataFrame(
        {"Accuracy": acc, "Recall": recall, "Precision": precision, "F1 Score": f1,}, index = [0]
    )

    return df_perf

# %% [markdown]
# ## Initial Model Building (Model 0)

# %% [markdown]
# - Let's start with a neural network consisting of
#   - just one hidden layer of 7 neurons respectively
#   - activation function of ReLU.
#   - SGD as the optimizer

# %%
# defining the batch size and # epochs upfront as we'll be using the same values for all models
epochs = 50    # Complete the code to enter the number of epochs to be used in all models
batch_size = 64    # Complete the code to enter the batch size to be used in all models
tf.random.set_seed(42)
np.random.seed(42)

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
model_0 = Sequential()
model_0.add(Dense( 64 ,activation="relu",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and the activation function
model_0.add(Dense( 1 ,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_0.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         2,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,689 (10.50 KB)
#  Trainable params: 2,689 (10.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.SGD()   # defining SGD as the optimizer to be used
# model_0.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_0.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_0.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_0.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_0.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs)
end=time.time()
# Out:
# Epoch 1/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.3446 - loss: 0.1446 - val_Recall: 0.4955 - val_loss: 0.1074
# Epoch 2/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.5721 - loss: 0.0985 - val_Recall: 0.6351 - val_loss: 0.0931
# Epoch 3/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.6520 - loss: 0.0872 - val_Recall: 0.6802 - val_loss: 0.0866
# Epoch 4/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.6892 - loss: 0.0810 - val_Recall: 0.7252 - val_loss: 0.0828
# Epoch 5/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.7252 - loss: 0.0768 - val_Recall: 0.7432 - val_loss: 0.0800
# Epoch 6/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.7432 - loss: 0.0737 - val_Recall: 0.7523 - val_loss: 0.0780
# Epoch 7/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.7568 - loss: 0.0713 - val_Recall: 0.7658 - val_loss: 0.0763
# Epoch 8/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.7646 - loss: 0.0694 - val_Recall: 0.7658 - val_loss: 0.0749
# Epoch 9/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.7714 - loss: 0.0678 - val_Recall: 0.7703 - val_loss: 0.0737
# Epoch 10/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.7782 - loss: 0.0663 - val_Recall: 0.7748 - val_loss: 0.0727
# Epoch 11/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.7860 - loss: 0.0651 - val_Recall: 0.7793 - val_loss: 0.0718
# Epoch 12/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.7883 - loss: 0.0640 - val_Recall: 0.7793 - val_loss: 0.0710
# Epoch 13/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.
train_perf
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.990125  0.918986    0.98544   0.94946

# %%
model_0_val_perf = model_performance_classification(model_0,X_val,y_val)
model_0_val_perf
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0   0.98925  0.909513   0.986649  0.944343

# %% [markdown]
# Let's check the classification reports.

# %%
y_train_pred_0 = model_0.predict(X_train)
y_val_pred_0 = model_0.predict(X_val)
# Out:
#   1/500 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 954us/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
print("Classification Report - Train data Model_0",end="\n\n")
cr_train_model_0 = classification_report(y_train,y_train_pred_0>0.3)
print(cr_train_model_0)
# Out:
# Classification Report - Train data Model_0
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00     15112
#          1.0       0.95      0.88      0.91       888
#
#     accuracy                           0.99     16000
#    macro avg       0.97      0.94      0.95     16000
# weighted avg       0.99      0.99      0.99     16000

# %% [markdown]
# # **Model Performance Improvement**

# %% [markdown]
# ## Model 1

# %% [markdown]
# - Let's try adding another layer to see if we can improve our model's performance.

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
model_1 = Sequential()
model_1.add(Dense( 64 ,activation="relu",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and activation function
model_1.add(Dense(32,activation="relu")) # Complete the code to define the number of neurons and activation function
model_1.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         2,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,737 (18.50 KB)
#  Trainable params: 4,737 (18.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.SGD()   # defining SGD as the optimizer to be used
# model_1.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_1.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_1.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_1.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_1.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs)
end=time.time()
# Out:
# Epoch 1/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.3559 - loss: 0.1529 - val_Recall: 0.5135 - val_loss: 0.1115
# Epoch 2/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.5552 - loss: 0.1026 - val_Recall: 0.6216 - val_loss: 0.0952
# Epoch 3/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.6453 - loss: 0.0891 - val_Recall: 0.7027 - val_loss: 0.0867
# Epoch 4/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.6914 - loss: 0.0811 - val_Recall: 0.7387 - val_loss: 0.0809
# Epoch 5/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7275 - loss: 0.0755 - val_Recall: 0.7477 - val_loss: 0.0766
# Epoch 6/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7511 - loss: 0.0712 - val_Recall: 0.7523 - val_loss: 0.0732
# Epoch 7/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7680 - loss: 0.0677 - val_Recall: 0.7568 - val_loss: 0.0705
# Epoch 8/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.7815 - loss: 0.0648 - val_Recall: 0.7658 - val_loss: 0.0684
# Epoch 9/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.7905 - loss: 0.0624 - val_Recall: 0.7748 - val_loss: 0.0667
# Epoch 10/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7995 - loss: 0.0603 - val_Recall: 0.7838 - val_loss: 0.0654
# Epoch 11/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8029 - loss: 0.0585 - val_Recall: 0.7883 - val_loss: 0.0643
# Epoch 12/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8097 - loss: 0.0570 - val_Recall: 0.8018 - val_loss: 0.0633
# Epoch 13/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8153 - loss: 0.0556 - val_Recall: 0.8063 - val_loss: 0.0625
# Epoch 14/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8288 - loss: 0.0544 - val_Recall: 0.8108 - val_loss: 0.0619
# Epoch 15/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8322 - loss: 0.0533 - val_Recall: 0.8153 - val_loss: 0.0613
# Epoch 16/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8356 - loss: 0.0524 - val_Recall: 0.8198 - val_loss: 0.0608
# Epoch 17/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8390 - loss: 0.0515 - val_Recall: 0.8243 - val_loss: 0.0604
# Epoch 18/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8446 - loss: 0.0507 - val_Recall: 0.8243 - val_loss: 0.0600
# Epoch 19/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8502 - loss: 0.0500 - val_Recall: 0.8288 - val_loss: 0.0597
# Epoch 20/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8514 - loss: 0.0493 - val_Recall: 0.8288 - val_loss: 0.0594
# Epoch 21/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8547 - loss: 0.0487 - val_Recall: 0.8288 - val_loss: 0.0592
# Epoch 22/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8570 - loss: 0.0481 - val_Recall: 0.8378 - val_loss: 0.0590
# Epoch 23/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8592 - loss: 0.0475 - val_Recall: 0.8423 - val_loss: 0.0588
# Epoch 24/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8615 - loss: 0.0470 - val_Recall: 0.8423 - val_loss: 0.0586
# Epoch 25/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8637 - loss: 0.0465 - val_Recall: 0.8423 - val_loss: 0.0584
# Epoch 26/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8649 - loss: 0.0460 - val_Recall: 0.8423 - val_loss: 0.0583
# Epoch 27/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8649 - loss: 0.0455 - val_Recall: 0.8423 - val_loss: 0.0581
# Epoch 28/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8660 - loss: 0.0450 - val_Recall: 0.8423 - val_loss: 0.0580
# Epoch 29/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8694 - loss: 0.0446 - val_Recall: 0.8423 - val_loss: 0.0579
# Epoch 30/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8705 - loss: 0.0442 - val_Recall: 0.8423 - val_loss: 0.0577
# Epoch 31/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8716 - loss: 0.0437 - val_Recall: 0.8423 - val_loss: 0.0576
# Epoch 32/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8716 - loss: 0.0433 - val_Recall: 0.8423 - val_loss: 0.0575
# Epoch 33/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8727 - loss: 0.0429 - val_Recall: 0.8423 - val_loss: 0.0575
# Epoch 34/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8761 - loss: 0.0425 - val_Recall: 0.8423 - val_loss: 0.0574
# Epoch 35/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8773 - loss: 0.0422 - val_Recall: 0.8423 - val_loss: 0.0573
# Epoch 36/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8773 - loss: 0.0418 - val_Recall: 0.8423 - val_loss: 0.0572
# Epoch 37/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8784 - loss: 0.0414 - val_Recall: 0.8423 - val_loss: 0.0571
# Epoch 38/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8784 - loss: 0.0411 - val_Recall: 0.8468 - val_loss: 0.0571
# Epoch 39/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8795 - loss: 0.0408 - val_Recall: 0.8468 - val_loss: 0.0570
# Epoch 40/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8795 - loss: 0.0404 - val_Recall: 0.8468 - val_loss: 0.0570
# Epoch 41/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8784 - loss: 0.0401 - val_Recall: 0.8468 - val_loss: 0.0569
# Epoch 42/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8784 - loss: 0.0398 - val_Recall: 0.8468 - val_loss: 0.0569
# Epoch 43/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8784 - loss: 0.0395 - val_Recall: 0.8468 - val_loss: 0.0569
# Epoch 44/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8784 - loss: 0.0392 - val_Recall: 0.8514 - val_loss: 0.0568
# Epoch 45/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8784 - loss: 0.0390 - val_Recall: 0.8514 - val_loss: 0.0567
# Epoch 46/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8806 - loss: 0.0387 - val_Recall: 0.8514 - val_loss: 0.0568
# Epoch 47/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8806 - loss: 0.0384 - val_Recall: 0.8559 - val_loss: 0.0567
# Epoch 48/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8806 - loss: 0.0382 - val_Recall: 0.8559 - val_loss: 0.0568
# Epoch 49/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8818 - loss: 0.0380 - val_Recall: 0.8559 - val_loss: 0.0567
# Epoch 50/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8806 - loss: 0.0377 - val_Recall: 0.8604 - val_loss: 0.0567

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  26.48760151863098

# %%
plot(history,'loss')

# %%
model_1_train_perf = model_performance_classification(model_1,X_train,y_train)
model_1_train_perf
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0     0.993  0.940647   0.992118   0.96478

# %%
model_1_val_perf = model_performance_classification(model_1,X_val,y_val)
model_1_val_perf
# Out:
#   1/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0   0.99075  0.929386   0.980696  0.953407

# %%
y_train_pred_1 = model_1.predict(X_train)
y_val_pred_1 = model_1.predict(X_val)
# Out:
#  56/500 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step

# %%
print("Classification Report - Train data Model_1", end="\n\n")
cr_train_model_1 = classification_report(y_train,y_train_pred_1 > 0.5)
print(cr_train_model_1)
# Out:
# Classification Report - Train data Model_1
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00     15112
#          1.0       0.99      0.88      0.93       888
#
#     accuracy                           0.99     16000
#    macro avg       0.99      0.94      0.96     16000
# weighted avg       0.99      0.99      0.99     16000

# %%
print("Classification Report - Validation data Model_1", end="\n\n")
cr_val_model_1 = classification_report(y_val,y_val_pred_1 > 0.5)
print(cr_val_model_1)
# Out:
# Classification Report - Validation data Model_1
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      3778
#          1.0       0.97      0.86      0.91       222
#
#     accuracy                           0.99      4000
#    macro avg       0.98      0.93      0.95      4000
# weighted avg       0.99      0.99      0.99      4000

# %% [markdown]
# ## Model 2

# %% [markdown]
# To introduce Regularization in our model, let's set the dropout to 50% after adding the first hidden layer. This step will randomly drop 50% of the neurons before proceeding to the next layer, reducing overfitting.

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
# Epoch 37/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7917 - loss: 0.0624 - val_Recall: 0.8378 - val_loss: 0.0587
# Epoch 38/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7950 - loss: 0.0620 - val_Recall: 0.8423 - val_loss: 0.0584
# Epoch 39/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7894 - loss: 0.0614 - val_Recall: 0.8514 - val_loss: 0.0584
# Epoch 40/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8007 - loss: 0.0592 - val_Recall: 0.8423 - val_loss: 0.0582
# Epoch 41/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8029 - loss: 0.0601 - val_Recall: 0.8514 - val_loss: 0.0579
# Epoch 42/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8052 - loss: 0.0595 - val_Recall: 0.8468 - val_loss: 0.0575
# Epoch 43/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8018 - loss: 0.0596 - val_Recall: 0.8514 - val_loss: 0.0571
# Epoch 44/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8164 - loss: 0.0581 - val_Recall: 0.8514 - val_loss: 0.0573
# Epoch 45/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8176 - loss: 0.0567 - val_Recall: 0.8514 - val_loss: 0.0572
# Epoch 46/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8086 - loss: 0.0580 - val_Recall: 0.8514 - val_loss: 0.0569
# Epoch 47/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.8097 - loss: 0.0574 - val_Recall: 0.8423 - val_loss: 0.0568
# Epoch 48/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8153 - loss: 0.0541 - val_Recall: 0.8423 - val_loss: 0.0569
# Epoch 49/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8086 - loss: 0.0565 - val_Recall: 0.8514 - val_loss: 0.0566
# Epoch 50/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8164 - loss: 0.0556 - val_Recall: 0.8514 - val_loss: 0.0568

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  27.847524642944336

# %%
plot(history,'loss')

# %% [markdown]
# Lets check the model performance of model_2 on training and validation data respectively.

# %%
model_2_train_perf = model_performance_classification(model_2,X_train,y_train)
model_2_train_perf
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0   0.99175  0.935215   0.984888  0.958538

# %%
model_2_val_perf = model_performance_classification(model_2,X_val,y_val)
model_2_val_perf
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0    0.9895  0.924485   0.972933   0.94723

# %%
y_train_pred_2 = model_2.predict(X_train)
y_val_pred_2 = model_2.predict(X_val)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step

# %% [markdown]
# Lets check the classification report of model_2 on training and validation data respectively.

# %%
print("Classification Report - Train data Model_2", end="\n\n")
cr_train_model_2 = classification_report(y_train,y_train_pred_2 > 0.5)
print(cr_train_model_2)
# Out:
# Classification Report - Train data Model_2
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00     15112
#          1.0       0.98      0.87      0.92       888
#
#     accuracy                           0.99     16000
#    macro avg       0.98      0.94      0.96     16000
# weighted avg       0.99      0.99      0.99     16000

# %%
print("Classification Report - Validation data Model_2", end="\n\n")
cr_val_model_2 = classification_report(y_val , y_val_pred_2 > 0.5)
print(cr_val_model_2)
# Out:
# Classification Report - Validation data Model_2
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      3778
#          1.0       0.95      0.85      0.90       222
#
#     accuracy                           0.99      4000
#    macro avg       0.97      0.92      0.95      4000
# weighted avg       0.99      0.99      0.99      4000

# %% [markdown]
# ## Model 3

# %% [markdown]
# As we have are dealing with an imbalance in class distribution, we should also be using class weights to allow the model to give proportionally more importance to the minority class.

# %%
# # Calculate class weights for imbalanced dataset
# cw = (y_train.shape[0]) / np.bincount(y_train.astype(int)) # Convert y_train to integers

# # Create a dictionary mapping class indices to their respective class weights
# cw_dict = {}
# for i in range(cw.shape[0]):
#     cw_dict[i] = cw[i]

# cw_dict

# Drop-in replacement — more stable, same ratio, better gradient behaviour
from sklearn.utils.class_weight import compute_class_weight

# weights = compute_class_weight('balanced', classes=np.array([0,1]), y=y_train)
# cw_dict = {0: weights[0], 1: weights[1]}
# → {0: 0.529, 1: 9.009}
# cw_dict = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train) 

# cw_dict = {0: 1, 1: 24}

# import numpy as np
# from sklearn.utils import class_weight

# 1. Calculate the weights (returns an array)
weights = compute_class_weight(
    class_weight='balanced', 
    classes=np.unique(y_train), 
    y=y_train
)

# 2. Convert to a dictionary mapping class index to weight
cw_dict = dict(zip(np.unique(y_train), weights))
#cw_dict = {0: 1, 1: 50}
print(cw_dict)
# Out:
# {np.float64(0.0): np.float64(0.5293806246691372), np.float64(1.0): np.float64(9.00900900900901)}

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
# Epoch 35/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9122 - loss: 0.1627 - val_Recall: 0.8964 - val_loss: 0.1076
# Epoch 36/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9077 - loss: 0.1698 - val_Recall: 0.8919 - val_loss: 0.1048
# Epoch 37/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9110 - loss: 0.1603 - val_Recall: 0.8919 - val_loss: 0.0997
# Epoch 38/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9088 - loss: 0.1574 - val_Recall: 0.8964 - val_loss: 0.1075
# Epoch 39/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9144 - loss: 0.1580 - val_Recall: 0.8964 - val_loss: 0.1071
# Epoch 40/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9144 - loss: 0.1559 - val_Recall: 0.8919 - val_loss: 0.1094
# Epoch 41/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9122 - loss: 0.1583 - val_Recall: 0.8874 - val_loss: 0.1032
# Epoch 42/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9099 - loss: 0.1565 - val_Recall: 0.8919 - val_loss: 0.1022
# Epoch 43/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9088 - loss: 0.1545 - val_Recall: 0.8919 - val_loss: 0.0976
# Epoch 44/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9155 - loss: 0.1549 - val_Recall: 0.8919 - val_loss: 0.0995
# Epoch 45/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9088 - loss: 0.1545 - val_Recall: 0.8919 - val_loss: 0.0987
# Epoch 46/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9110 - loss: 0.1574 - val_Recall: 0.8919 - val_loss: 0.0982
# Epoch 47/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9122 - loss: 0.1495 - val_Recall: 0.8964 - val_loss: 0.1031
# Epoch 48/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9155 - loss: 0.1495 - val_Recall: 0.8964 - val_loss: 0.0973
# Epoch 49/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9144 - loss: 0.1540 - val_Recall: 0.8919 - val_loss: 0.0952
# Epoch 50/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9155 - loss: 0.1474 - val_Recall: 0.8919 - val_loss: 0.1001

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  33.230310916900635

# %%
plot(history,'loss')

# %% [markdown]
# Lets check the model performance of model_3 on training and validation data respectively.

# %%
model_3_train_perf = model_performance_classification(model_3,X_train,y_train)
model_3_train_perf
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.991688  0.957441   0.962842  0.960124

# %%
model_3_val_perf = model_performance_classification(model_3,X_val,y_val)
model_3_val_perf
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0     0.989  0.943299   0.950956   0.94709

# %%
y_train_pred_3 = model_3.predict(X_train)
y_val_pred_3 = model_3.predict(X_val)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step

# %% [markdown]
# Lets check the classification report of model_3 on training and validation data respectively.

# %%
print("Classification Report - Train data Model_3", end="\n\n")
cr_train_model_3 = classification_report(y_train,y_train_pred_3 > 0.5)
print(cr_train_model_3)
# Out:
# Classification Report - Train data Model_3
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     15112
#          1.0       0.93      0.92      0.92       888
#
#     accuracy                           0.99     16000
#    macro avg       0.96      0.96      0.96     16000
# weighted avg       0.99      0.99      0.99     16000

# %%
print("Classification Report - Validation data Model_3", end="\n\n")
cr_val_model_3 = classification_report(y_val,y_val_pred_3 > 0.5)
print(cr_val_model_3)
# Out:
# Classification Report - Validation data Model_3
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      3778
#          1.0       0.91      0.89      0.90       222
#
#     accuracy                           0.99      4000
#    macro avg       0.95      0.94      0.95      4000
# weighted avg       0.99      0.99      0.99      4000

# %% [markdown]
# ## Model 4

# %% [markdown]
# Since we have used only SGD optimizer till now, let's use another kind of optimizer and observe its impact on the model performmance.

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
model_4 = Sequential()
model_4.add(Dense(64,activation="relu",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and activation function
model_4.add(Dense(32,activation="relu")) # Complete the code to define the number of neurons and activation function
model_4.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_4.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         2,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,737 (18.50 KB)
#  Trainable params: 4,737 (18.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)    # defining Adam as the optimizer to be used
# model_4.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_4.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_4.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_4.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_4.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs)
end=time.time()
# Out:
# Epoch 1/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.5439 - loss: 0.1127 - val_Recall: 0.7613 - val_loss: 0.0685
# Epoch 2/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8153 - loss: 0.0574 - val_Recall: 0.8333 - val_loss: 0.0601
# Epoch 3/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8491 - loss: 0.0489 - val_Recall: 0.8468 - val_loss: 0.0579
# Epoch 4/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8626 - loss: 0.0447 - val_Recall: 0.8514 - val_loss: 0.0574
# Epoch 5/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8739 - loss: 0.0412 - val_Recall: 0.8604 - val_loss: 0.0572
# Epoch 6/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8795 - loss: 0.0391 - val_Recall: 0.8604 - val_loss: 0.0570
# Epoch 7/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.
# Epoch 47/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9403 - loss: 0.0136 - val_Recall: 0.8649 - val_loss: 0.0975
# Epoch 48/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9414 - loss: 0.0132 - val_Recall: 0.8649 - val_loss: 0.0985
# Epoch 49/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9381 - loss: 0.0140 - val_Recall: 0.8559 - val_loss: 0.1045
# Epoch 50/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9369 - loss: 0.0136 - val_Recall: 0.8694 - val_loss: 0.1032

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  30.140145540237427

# %%
plot(history,'loss')

# %% [markdown]
# Lets check the model performance ofr model_4 on training and validation data respectively

# %%
model_4_train_perf = model_performance_classification(model_4,X_train,y_train)
model_4_train_perf
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0   0.99625  0.966746   0.997453  0.981547

# %%
model_4_val_perf = model_performance_classification(model_4,X_val,y_val)
model_4_val_perf
# Out:
#   1/125 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0     0.991  0.933758   0.978684  0.954971

# %%
y_train_pred_4 = model_4.predict(X_train)
y_val_pred_4 = model_4.predict(X_val)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step

# %% [markdown]
# Lets check the classification report of model_4 on raining and validation data respectively.

# %%
print("Classification Report - Train data Model_4", end="\n\n")
cr_train_model_4 = classification_report(y_train,y_train_pred_4 > 0.5)
print(cr_train_model_4)
# Out:
# Classification Report - Train data Model_4
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     15112
#          1.0       1.00      0.93      0.97       888
#
#     accuracy                           1.00     16000
#    macro avg       1.00      0.97      0.98     16000
# weighted avg       1.00      1.00      1.00     16000

# %%
print("Classification Report - Validation data Model_4", end="\n\n")
cr_val_model_4 = classification_report(y_val,y_val_pred_4 > 0.5)
print(cr_val_model_4)
# Out:
# Classification Report - Validation data Model_4
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      3778
#          1.0       0.96      0.87      0.91       222
#
#     accuracy                           0.99      4000
#    macro avg       0.98      0.93      0.95      4000
# weighted avg       0.99      0.99      0.99      4000

# %% [markdown]
# ## Model 5

# %% [markdown]
# This time we will add more layers and dropout while using a different optimizer.

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
from tensorflow.keras.layers import Dropout
model_5 = Sequential()
model_5.add(Dense(128,activation="relu",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and activation function
model_5.add(Dropout(0.5)) #Complete the code to define the dropout rate
model_5.add(Dense(64,activation="relu")) # Complete the code to define the number of neurons and activation function
model_5.add(Dense(32, activation = "relu")) # Complete the code to define the number of neurons and activation function
model_5.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons and activation function

# %%
model_5.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         5,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,617 (61.00 KB)
#  Trainable params: 15,617 (61.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)    # defining Adam as the optimizer to be used
# model_5.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_5.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_5.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_5.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_5.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs)
end=time.time()
# Out:
# Epoch 1/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.4369 - loss: 0.1407 - val_Recall: 0.7568 - val_loss: 0.0773
# Epoch 2/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.6914 - loss: 0.0836 - val_Recall: 0.8108 - val_loss: 0.0665
# Epoch 3/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7680 - loss: 0.0705 - val_Recall: 0.8288 - val_loss: 0.0648
# Epoch 4/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7872 - loss: 0.0645 - val_Recall: 0.8243 - val_loss: 0.0610
# Epoch 5/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8119 - loss: 0.0588 - val_Recall: 0.8423 - val_loss: 0.0574
# Epoch 6/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8345 - loss: 0.0559 - val_Recall: 0.8423 - val_loss: 0.0592
# Epoch 7/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8457 - loss: 0.0529 - val_Recall: 0.8649 - val_loss: 0.0573
# Epoch 8/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8435 - loss: 0.0508 - val_Recall: 0.8694 - val_loss: 0.0587
# Epoch 9/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8378 - loss: 0.0511 - val_Recall: 0.8649 - val_loss: 0.0580
# Epoch 10/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8570 - loss: 0.0487 - val_Recall: 0.8559 - val_loss: 0.0597
# Epoch 11/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8637 - loss: 0.0470 - val_Recall: 0.8604 - val_loss: 0.0587
# Epoch 12/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8615 - loss: 0.0467 - val_Recall: 0.8694 - val_loss: 0.0597
# Epoch 13/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8660 - loss: 0.0438 - val_Recall: 0.8559 - val_loss: 0.0605
# Epoch 14/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8761 - loss: 0.0421 - val_Recall: 0.8649 - val_loss: 0.0631
# Epoch 15/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8626 - loss: 0.0456 - val_Recall: 0.8604 - val_loss: 0.0621
# Epoch 16/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.
val_perf
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy   Recall  Precision  F1 Score
# 0   0.99225  0.93654   0.988704  0.960963

# %%
y_train_pred_5 = model_5.predict(X_train)
y_val_pred_5 = model_5.predict(X_val)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step

# %% [markdown]
# Lets check the classification report of model_5 on training and validation data.

# %%
print("Classification Report - Train data Model_2", end="\n\n")
cr_train_model_5 = classification_report(y_train,y_train_pred_5 > 0.5)
print(cr_train_model_5)
# Out:
# Classification Report - Train data Model_2
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00     15112
#          1.0       1.00      0.91      0.95       888
#
#     accuracy                           0.99     16000
#    macro avg       0.99      0.96      0.97     16000
# weighted avg       0.99      0.99      0.99     16000

# %%
print("Classification Report - Validation data Model_2", end="\n\n")
cr_val_model_5 = classification_report(y_val,y_val_pred_5 > 0.5)
print(cr_val_model_5)
# Out:
# Classification Report - Validation data Model_2
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      3778
#          1.0       0.98      0.87      0.93       222
#
#     accuracy                           0.99      4000
#    macro avg       0.99      0.94      0.96      4000
# weighted avg       0.99      0.99      0.99      4000

# %% [markdown]
# ## Model 6

# %% [markdown]
# Let's see how does the model performance change when the model gives higher importance to the minority class

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
model_6 = Sequential()
model_6.add(Dense(256,activation="relu",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and activation function
model_6.add(Dropout(0.4)) # Complete the code to define the dropout rate
model_6.add(Dense(128,activation="relu")) # Complete the code to define the number of neurons and activation function
model_6.add(Dense(64, activation = "relu")) # Complete the code to define the number of neurons and activation function
model_6.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_6.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │        10,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 51,713 (202.00 KB)
#  Trainable params: 51,713 (202.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.SGD()
# model_6.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_6.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_6.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_6.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_6.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs,class_weight=cw_dict ) # Complete the code such that the model is biased towards the minority class
end=time.time()
# Out:
# Epoch 1/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8288 - loss: 0.4129 - val_Recall: 0.8919 - val_loss: 0.2250
# Epoch 2/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8829 - loss: 0.3161 - val_Recall: 0.8784 - val_loss: 0.1658
# Epoch 3/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8851 - loss: 0.2860 - val_Recall: 0.8739 - val_loss: 0.1329
# Epoch 4/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8941 - loss: 0.2565 - val_Recall: 0.8784 - val_loss: 0.1193
# Epoch 5/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8941 - loss: 0.2510 - val_Recall: 0.8784 - val_loss: 0.1187
# Epoch 6/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8986 - loss: 0.2299 - val_Recall: 0.8784 - val_loss: 0.1112
# Epoch 7/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8896 - loss: 0.2267 - val_Recall: 0.8784 - val_loss: 0.1071
# Epoch 8/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8986 - loss: 0.2150 - val_Recall: 0.8784 - val_loss: 0.1035
# Epoch 9/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8998 - loss: 0.2071 - val_Recall: 0.8874 - val_loss: 0.1087
# Epoch 10/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9032 - loss: 0.2061 - val_Recall: 0.8874 - val_loss: 0.1040
# Epoch 11/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9020 - loss: 0.1986 - val_Recall: 0.8829 - val_loss: 0.0978
# Epoch 12/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8998 - loss: 0.1936 - val_Recall: 0.8874 - val_loss: 0.1021
# Epoch 13/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9122 - loss: 0.1846 - val_Recall: 0.8829 - val_loss: 0.0984
# Epoch 14/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9020 - loss: 0.1874 - val_Recall: 0.8829 - val_loss: 0.0995
# Epoch 15/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9043 - loss: 0.1861 - val_Recall: 0.8874 - val_loss: 0.0954
# Epoch 16/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9088 - loss: 0.1838 - val_Recall: 0.8874 - val_loss: 0.1046
# Epoch 17/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9088 - loss: 0.1814 - val_Recall: 0.8784 - val_loss: 0.0993
# Epoch 18/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9054 - loss: 0.1771 - val_Recall: 0.8829 - val_loss: 0.0981
# Epoch 19/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9065 - loss: 0.1729 - val_Recall: 0.8784 - val_loss: 0.0983
# Epoch 20/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9088 - loss: 0.1717 - val_Recall: 0.8829 - val_loss: 0.0993
# Epoch 21/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9099 - loss: 0.1733 - val_Recall: 0.8829 - val_loss: 0.0982
# Epoch 22/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9077 - loss: 0.1715 - val_Recall: 0.8829 - val_loss: 0.0919
# Epoch 23/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9133 - loss: 0.1643 - val_Recall: 0.8829 - val_loss: 0.0928
# Epoch 24/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9077 - loss: 0.1685 - val_Recall: 0.8829 - val_loss: 0.0979
# Epoch 25/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9178 - loss: 0.1625 - val_Recall: 0.8919 - val_loss: 0.1012
# Epoch 26/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9133 - loss: 0.1626 - val_Recall: 0.8964 - val_loss: 0.0983
# Epoch 27/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9110 - loss: 0.1588 - val_Recall: 0.8874 - val_loss: 0.1030
# Epoch 28/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9099 - loss: 0.1580 - val_Recall: 0.8919 - val_loss: 0.0927
# Epoch 29/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9178 - loss: 0.1522 - val_Recall: 0.8874 - val_loss: 0.0861
# Epoch 30/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9122 - loss: 0.1582 - val_Recall: 0.8874 - val_loss: 0.0916
# Epoch 31/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9133 - loss: 0.1557 - val_Recall: 0.8919 - val_loss: 0.0987
# Epoch 32/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9133 - loss: 0.1544 - val_Recall: 0.8829 - val_loss: 0.0880
# Epoch 33/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9155 - loss: 0.1516 - val_Recall: 0.8874 - val_loss: 0.0904
# Epoch 34/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9133 - loss: 0.1540 - val_Recall: 0.8964 - val_loss: 0.0957
# Epoch 35/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9144 - loss: 0.1460 - val_Recall: 0.8964 - val_loss: 0.0947
# Epoch 36/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9144 - loss: 0.1539 - val_Recall: 0.8964 - val_loss: 0.0984
# Epoch 37/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9144 - loss: 0.1458 - val_Recall: 0.8964 - val_loss: 0.0924
# Epoch 38/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9178 - loss: 0.1513 - val_Recall: 0.8919 - val_loss: 0.0869
# Epoch 39/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9234 - loss: 0.1497 - val_Recall: 0.8874 - val_loss: 0.0937
# Epoch 40/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9155 - loss: 0.1473 - val_Recall: 0.8919 - val_loss: 0.0887
# Epoch 41/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9122 - loss: 0.1500 - val_Recall: 0.8874 - val_loss: 0.0865
# Epoch 42/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9167 - loss: 0.1464 - val_Recall: 0.8964 - val_loss: 0.0922
# Epoch 43/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9167 - loss: 0.1415 - val_Recall: 0.8964 - val_loss: 0.0906
# Epoch 44/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9178 - loss: 0.1404 - val_Recall: 0.8874 - val_loss: 0.0878
# Epoch 45/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9155 - loss: 0.1369 - val_Recall: 0.8964 - val_loss: 0.0981
# Epoch 46/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9212 - loss: 0.1373 - val_Recall: 0.8919 - val_loss: 0.0872
# Epoch 47/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9167 - loss: 0.1380 - val_Recall: 0.8919 - val_loss: 0.0901
# Epoch 48/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9167 - loss: 0.1378 - val_Recall: 0.8964 - val_loss: 0.0948
# Epoch 49/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9212 - loss: 0.1395 - val_Recall: 0.8919 - val_loss: 0.0882
# Epoch 50/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9167 - loss: 0.1351 - val_Recall: 0.8964 - val_loss: 0.0881

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  32.93717408180237

# %%
plot(history,'loss')

# %% [markdown]
# Lets check the model performance of model_6 on training and validation data.

# %%
model_6_train_perf = model_performance_classification(model_6,X_train,y_train)
model_6_train_perf
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#    Accuracy   Recall  Precision  F1 Score
# 0  0.991875  0.95966   0.962604  0.961127

# %%
model_6_val_perf = model_performance_classification(model_6,X_val,y_val)
model_6_val_perf
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0   0.98825  0.945022   0.943144   0.94408

# %%
y_train_pred_6 = model_6.predict(X_train)
y_val_pred_6 = model_6.predict(X_val)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# Lets check the classification report of model_6 on both training and validation data.

# %%
print("Classification Report - Train data Model_3", end="\n\n")
cr_train_model_6 = classification_report(y_train,y_train_pred_6 > 0.5)
print(cr_train_model_6)
# Out:
# Classification Report - Train data Model_3
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     15112
#          1.0       0.93      0.92      0.93       888
#
#     accuracy                           0.99     16000
#    macro avg       0.96      0.96      0.96     16000
# weighted avg       0.99      0.99      0.99     16000

# %%
print("Classification Report - Validation data Model_3", end="\n\n")
cr_val_model_6 = classification_report(y_val,y_val_pred_6 > 0.5)
print(cr_val_model_6)
# Out:
# Classification Report - Validation data Model_3
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      3778
#          1.0       0.89      0.90      0.89       222
#
#     accuracy                           0.99      4000
#    macro avg       0.94      0.95      0.94      4000
# weighted avg       0.99      0.99      0.99      4000

# %% [markdown]
# # **Model Performance Comparison and Final Model Selection**

# %% [markdown]
# Now, in order to select the final model, we will compare the performances of all the models for the training and test sets.

# %% [markdown]
# **Training Performance Comparison**

# %%
# training performance comparison

models_train_comp_df = pd.concat(
    [
        model_0_train_perf.T,
        model_1_train_perf.T,
        model_2_train_perf.T,
        model_3_train_perf.T,
        model_4_train_perf.T,
        model_5_train_perf.T,
        model_6_train_perf.T

    ],
    axis=1,
)
models_train_comp_df.columns = [
    "Model 0",
    "Model 1",
    "Model 2",
    "Model 3",
    "Model 4",
    "Model 5",
    "Model 6"
]
print("Training set performance comparison:")
models_train_comp_df
# Out:
# Training set performance comparison:
#             Model 0   Model 1   Model 2   Model 3   Model 4   Model 5  \
# Accuracy   0.990125  0.993000  0.991750  0.991688  0.996250  0.994875
# Recall     0.918986  0.940647  0.935215  0.957441  0.966746  0.955949
# Precision  0.985440  0.992118  0.984888  0.962842  0.997453  0.994975
# F1 Score   0.949460  0.964780  0.958538  0.960124  0.981547  0.974557
#
#             Model 6
# Accuracy   0.991875
# Recall     0.959660
# Precision  0.962604
# F1 Score   0.961127

# %% [markdown]
# **Validation Performance Comparison**

# %%
# Validation performance comparison

models_val_comp_df = pd.concat(
    [
        model_0_val_perf.T,
        model_1_val_perf.T,
        model_2_val_perf.T,
        model_3_val_perf.T,
        model_4_val_perf.T,
        model_5_val_perf.T,
        model_6_val_perf.T

    ],
    axis=1,
)
models_val_comp_df.columns = [
    "Model 0",
    "Model 1",
    "Model 2",
    "Model 3",
    "Model 4",
    "Model 5",
    "Model 6"
]
print("Validation set performance comparison:")
models_val_comp_df
# Out:
# Validation set performance comparison:
#             Model 0   Model 1   Model 2   Model 3   Model 4   Model 5  \
# Accuracy   0.989250  0.990750  0.989500  0.989000  0.991000  0.992250
# Recall     0.909513  0.929386  0.924485  0.943299  0.933758  0.936540
# Precision  0.986649  0.980696  0.972933  0.950956  0.978684  0.988704
# F1 Score   0.944343  0.953407  0.947230  0.947090  0.954971  0.960963
#
#             Model 6
# Accuracy   0.988250
# Recall     0.945022
# Precision  0.943144
# F1 Score   0.944080

# %% [markdown]
# **Checking the performance of the best model on the test set**

# %%
# best_model = model_0 ## Uncomment this line in case the best model is model_0
# best_model = model_1 ## Uncomment this line in case the best model is model_1
# best_model = model_2 ## Uncomment this line in case the best model is model_2
# best_model = model_3 ## Uncomment this line in case the best model is model_3
# best_model = model_4 ## Uncomment this line in case the best model is model_4
best_model = model_5 ## Uncomment this line in case the best model is model_5
#best_model = model_6 ## Uncomment this line in case the best model is model_6

# %%
# Test set performance for the best model
best_model_test_perf = model_performance_classification(best_model,X_test,y_test)
best_model_test_perf
# Out:
#   1/157 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0    0.9916  0.933867   0.986105  0.958308

# %%
y_test_pred_best = best_model.predict(X_test)

cr_test_best_model = classification_report(y_test, y_test_pred_best>0.3) # Check the classification report of best model on test data.
print(cr_test_best_model)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      4718
#          1.0       0.97      0.87      0.92       282
#
#     accuracy                           0.99      5000
#    macro avg       0.98      0.94      0.96      5000
# weighted avg       0.99      0.99      0.99      5000

# %% [markdown]
# # **Actionable Insights and Recommendations**

# %% [markdown]
# - Write down actionable insights here

# %% [markdown]
# - Write down business recommendations here
